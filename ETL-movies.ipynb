# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
ratings = "Resources/IMDb_ratings.csv"
imdb_ratings_df = pd.read_csv(ratings)
imdb_ratings_df.head(1)
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
#
#    females_30age_votes  females_45age_avg_vote  females_45age_votes  \
# 0                 13.0                     4.5                  4.0
#
#    top1000_voters_rating  top1000_voters_votes  us_voters_rating  \
# 0                    5.7                  34.0               6.4
#
#    us_voters_votes  non_us_voters_rating  non_us_voters_votes
# 0             51.0                   6.0                 70.0
#
# [1 rows x 49 columns]

# %%
del imdb_ratings_df [["total_votes", "mean_vote", "median_vote", "votes_10", "votes_9", "votes_8", "votes_7"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-3809a35e7ab6> in <module>
# ----> 1 del imdb_ratings_df [["total_votes", "mean_vote", "median_vote", "votes_10", "votes_9", "votes_8", "votes_7"]]
#
# ~\anaconda03\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3709             # there was no match, this call should raise the appropriate
#    3710             # exception:
# -> 3711             loc = self.axes[-1].get_loc(key)
#    3712             self._mgr.idelete(loc)
#    3713
#
# ~\anaconda03\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2893             casted_key = self._maybe_cast_indexer(key)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#    2897                 raise KeyError(key) from err
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '['total_votes', 'mean_vote', 'median_vote', 'votes_10', 'votes_9', 'votes_8', 'votes_7']' is an invalid key

# %%
imdbtitle = "Resources/IMDb_movies.csv"
imdb_titles_df = pd.read_csv(imdbtitle)
imdb_titles_df.head(1)
# Out:
# C:\Users\ddray\anaconda03\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   imdb_title_id       title original_title  year date_published    genre  \
# 0     tt0000009  Miss Jerry     Miss Jerry  1894     1894-10-09  Romance
#
#    duration country language         director  ...  \
# 0        45     USA     None  Alexander Black  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
#
#                                          description avg_vote votes  budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154     NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
#
#    reviews_from_critics
# 0                   2.0
#
# [1 rows x 22 columns]

# %%
netflixtitles = "Resources/netflix_titles.csv"
netflix_titles_df = pd.read_csv(netflixtitles)
netflix_titles_df.head(1)
# Out:
#   show_id     type title director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 cast country       date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          description
# 0  In a future where the elite inhabit an island ...

# %%
disney_plus_shows = "Resources/disney_plus_shows.csv"
disney_plus_shows_df = pd.read_csv(disney_plus_shows)
disney_plus_shows_df.head(1)
# Out:
#      imdb_id                       title  \
# 0  tt0147800  10 Things I Hate About You
#
#                                                 plot   type  rated  year  \
# 0  A pretty, popular teenager can't go out on a d...  movie  PG-13  1999
#
#   released_at   added_at runtime                   genre    director  \
# 0   31-Mar-99  12-Nov-19  97 min  Comedy, Drama, Romance  Gil Junger
#
#                           writer  \
# 0  Karen McCullah, Kirsten Smith
#
#                                               actors         language country  \
# 0  Heath Ledger, Julia Stiles, Joseph Gordon-Levi...  English, French     USA
#
#                      awards  metascore  imdb_rating imdb_votes
# 0  2 wins & 13 nominations.       70.0          7.3    283,945

# %%
del imdb_ratings_df[""]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-8008e2359770> in <module>
# ----> 1 new_imbd_ratings = imdb_ratings_df[[ "imbd_title_id", "weighted_average_vote"]]
#       2 new_imbd_ratings
#
# ~\anaconda03\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda03\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda03\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['imbd_title_id'] not in index"
